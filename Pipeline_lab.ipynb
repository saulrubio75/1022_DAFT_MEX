# %% [markdown]
# <a href="https://colab.research.google.com/github/saulrubio75/1022_DAFT_MEX/blob/main/Pipeline_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
GoT_df = pd.read_csv('/content/drive/MyDrive/Game_of_Thrones.csv')
GoT_df.head()
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
# 2       1                        3                         3
# 3       1                        4                         4
# 4       1                        5                         5
#
#                     Title of the Episode  Running Time (Minutes)  \
# 0                       Winter Is Coming                      61
# 1                          The Kingsroad                      55
# 2                              Lord Snow                      57
# 3  Cripples, Bastards, and Broken Things                      55
# 4                  The Wolf and the Lion                      54
#
#       Directed by                  Written by Original Air Date  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1  Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# ...

# %%
GoT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Season                               73 non-null     int64
#  1   No. of Episode (Season)              73 non-null     int64
#  2   No. of Episode (Overall)             73 non-null     int64
#  3   Title of the Episode                 73 non-null     object
#  4   Running Time (Minutes)               73 non-null     int64
#  5   Directed by                          73 non-null     object
#  6   Written by                           73 non-null     object
#  7   Original Air Date                    73 non-null     object
#  8   U.S. Viewers (Millions)              73 non-null     float64
#  9   Music by                             73 non-null     object
#  10  Cinematography by                    73 non-null     object
# ...

# %%
GoT_df.columns
# Out:
# Index(['Season', 'No. of Episode (Season)', 'No. of Episode (Overall)',
#        'Title of the Episode', 'Running Time (Minutes)', 'Directed by',
#        'Written by', 'Original Air Date', 'U.S. Viewers (Millions)',
#        'Music by', 'Cinematography by', 'Editing by', 'IMDb Rating',
#        'Rotten Tomatoes Rating (Percentage)', 'Metacritic Ratings', 'Ordered',
#        'Filming Duration', 'Novel(s) Adapted', 'Synopsis'],
#       dtype='object')

# %%
GoT_df['IMDb_Rating'] = GoT_df['IMDb Rating'] * 10 
GoT_df['Metacritic_Ratings'] = GoT_df['Metacritic Ratings'] * 10   

GoT_df['IMDb_Rating']
# Out:
# 0     89.0
# 1     86.0
# 2     85.0
# 3     86.0
# 4     90.0
#       ...
# 68    79.0
# 69    75.0
# 70    55.0
# 71    60.0
# 72    40.0
# Name: IMDb_Rating, Length: 73, dtype: float64

# %%
GoT_df.replace(to_replace=['IMDb_Rating'], value=['IMDb Rating'] ) 
GoT_df.drop(columns=['IMDb Rating'])
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# ..     ...                      ...                       ...
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# ...

# %%
GoT_df.replace(to_replace=['Metacritic_Ratings'], value=['Metacritic Ratings'] ) 
GoT_df.drop(columns=['Metacritic Ratings'])
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# ..     ...                      ...                       ...
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# ...

# %%
GoT_df.columns
# Out:
# Index(['Season', 'No. of Episode (Season)', 'No. of Episode (Overall)',
#        'Title of the Episode', 'Running Time (Minutes)', 'Directed by',
#        'Written by', 'Original Air Date', 'U.S. Viewers (Millions)',
#        'Music by', 'Cinematography by', 'Editing by', 'IMDb Rating',
#        'Rotten Tomatoes Rating (Percentage)', 'Metacritic Ratings', 'Ordered',
#        'Filming Duration', 'Novel(s) Adapted', 'Synopsis', 'IMDb_Rating',
#        'Metacritic_Ratings'],
#       dtype='object')

# %%
NGoT_df = ['Season', 'No. of Episode (Season)', 'No. of Episode (Overall)',
       'Title of the Episode', 'Running Time (Minutes)', 'Directed by',
       'Written by', 'Original Air Date', 'U.S. Viewers (Millions)',
       'Music by', 'Cinematography by', 'Editing by', 'IMDb_Rating',
       'Rotten Tomatoes Rating (Percentage)', 'Metacritic_Ratings', 'Ordered',
       'Filming Duration', 'Novel(s) Adapted', 'Synopsis']  

GoT_df = GoT_df[NGoT_df] 
GoT_df.head(2)
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
#
#   Title of the Episode  Running Time (Minutes)     Directed by  \
# 0     Winter Is Coming                      61  Tim Van Patten
# 1        The Kingsroad                      55  Tim Van Patten
#
#                    Written by Original Air Date  U.S. Viewers (Millions)  \
# 0  David Benioff, D. B. Weiss       17-Apr-2011                     2.22
# 1  David Benioff, D. B. Weiss       24-Apr-2011                     2.20
#
#         Music by Cinematography by         Editing by  IMDb_Rating  \
# 0  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey         89.0
# 1  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey         86.0
#
#    Rotten Tomatoes Rating (Percentage)  Metacritic_Ratings        Ordered  \
# 0                                  100                91.0  March 2, 2010
# ...

# %%
GoT_df['Average Rating'] = (GoT_df['IMDb_Rating'] + GoT_df['Rotten Tomatoes Rating (Percentage)'] + GoT_df['Metacritic_Ratings']) / 3 
GoT_df['Average Rating']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0     93.333333
# 1     91.666667
# 2     84.333333
# 3     92.333333
# 4     91.666667
#         ...
# 68    75.000000
# 69    63.666667
# 70    47.333333
# 71    47.666667
# 72    37.666667
# Name: Average Rating, Length: 73, dtype: float64

# %%
NGoT_df = ['Season', 'No. of Episode (Season)', 'No. of Episode (Overall)',
       'Title of the Episode', 'Running Time (Minutes)', 'Directed by',
       'Written by', 'Original Air Date', 'U.S. Viewers (Millions)',
       'Music by', 'Cinematography by', 'Editing by', 'IMDb_Rating',
       'Rotten Tomatoes Rating (Percentage)', 'Metacritic_Ratings', 'Average Rating', 'Ordered',
       'Filming Duration']   

GoT_df = GoT_df[NGoT_df]       
GoT_df.head(7)
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
# 2       1                        3                         3
# 3       1                        4                         4
# 4       1                        5                         5
# 5       1                        6                         6
# 6       1                        7                         7
#
#                     Title of the Episode  Running Time (Minutes)  \
# 0                       Winter Is Coming                      61
# 1                          The Kingsroad                      55
# 2                              Lord Snow                      57
# 3  Cripples, Bastards, and Broken Things                      55
# 4                  The Wolf and the Lion                      54
# 5                         A Golden Crown                      52
# ...

# %%
Season8 = GoT_df[67:] 
Season8
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 67       8                        1                        68
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#               Title of the Episode  Running Time (Minutes)  \
# 67                      Winterfell                      53
# 68  A Knight of the Seven Kingdoms                      57
# 69                  The Long Night                      81
# 70          The Last of the Starks                      77
# 71                       The Bells                      77
# 72                 The Iron Throne                      78
#
#                     Directed by                  Written by Original Air Date  \
# ...

# %%
Season8.to_csv('Season8.csv')
